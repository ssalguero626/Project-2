# %%
import pandas as pd
import os

# %%
# Define path to csv file

nyc_311_calls_df = pd.read_csv(r'C:\Users\ssalg\Desktop\Project-2\Resources\311_service_requests_4Q19.csv')

# %%
nyc_311_calls_df
# Out:
#         Unique_Key             Created_Date              Closed_Date Agency  \
# 0         43861543  2019-09-22T11:38:12.000                      NaN    DPR
# 1         43867439  2019-09-22T11:38:28.000  2019-09-22T12:16:31.000   NYPD
# 2         43868018  2019-09-22T11:39:20.000                      NaN    TLC
# 3         43865372  2019-09-22T11:39:25.000  2019-09-26T13:02:49.000    DPR
# 4         43863796  2019-09-22T11:39:38.000  2019-09-22T20:09:28.000   NYPD
# ...            ...                      ...                      ...    ...
# 204267    45054999  2019-12-01T01:58:07.000                      NaN   NYPD
# 204268    45052046  2019-12-01T01:58:23.000                      NaN   NYPD
# 204269    45049329  2019-12-01T01:59:08.000                      NaN   NYPD
# 204270    45054936  2019-12-01T01:59:41.000                      NaN   NYPD
# 204271    45050101  2019-12-01T02:04:01.000                      NaN    DOT
#
# ...

# %%
nyc_311_calls_df.to_html('nyc_311_calls.html')
